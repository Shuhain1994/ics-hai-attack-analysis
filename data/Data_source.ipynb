# %%
https://www.kaggle.com/code/kerneler/starter-hai-security-dataset-7355467a-2/input?select=hai-1.0

Normal_data: normal_20191101T200000_to_20191104T150000.csv
Attack:_data: abnormal_20191029T110000_to_20191101T200000.csv
